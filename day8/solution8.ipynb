# %%
import pandas as pd
import numpy as np

with open('input') as f:
    lines_bck = f.read().splitlines()

lines_bck
# df = pd.read_csv('input', header=None, dtype=str)
# df
lines = [x.split('|') for x in lines_bck]
linesInp = [x[0].split() for x in lines]
linesOut = [x[1].split() for x in lines]
# lines = [x.replace(' -> ',',') for x in lines_bck]
# lenlines = len(lines)
# print(lenlines)3
# lines = [int(x) for x in lines]
print(linesInp[0])
print(linesOut[0])
# Out:
# ['cdafg', 'dage', 'fgdaec', 'cdbfgae', 'cge', 'gcbdfa', 'fdceb', 'gfceab', 'ge', 'ecfgd']
# ['eg', 'eg', 'dfecag', 'ge']

# %%
lines_bck
# Out:
# ['cdafg dage fgdaec cdbfgae cge gcbdfa fdceb gfceab ge ecfgd | eg eg dfecag ge',
#  'efgcabd edacgf gfaec deg dg decga dcfg dbgafe bfgcae abced | deg baced fegac aefbcg',
#  'egacf dfbeg dec efcgd cfad cfagde fabcgde dc agbecf bgdeac | gcadef eacgbf egdfb bgdfe',
#  'dc cgefb cdf bdfgc adbc gafdec cbagfd gfbad dbcagfe gbedaf | cd cd agfbd bdac',
#  'dcbafg gadeb faegb cfbga ef gfe feca aegfbc cebgdf dfabceg | faec ceaf bcedgaf cfbga',
#  'bcf adbcef cbgdfe dbceag gcdbe dcafg egadcbf fb dgfcb gebf | cbgedf cbfdae aegbcd bf',
#  'dfge dg fbgce ecgfdb fcabdg bafgec cdg cbdae gecbd ecgdabf | eafcgbd gd cfgbde cdg',
#  'fadbg badfe faebcd gab ebfgad bfceag gfbcd gade adcebfg ag | gbfdea aedg becfad aedfbcg',
#  'gcfbd dga bfdcga gafdbec dcafg defac ag adbfeg acbg bfdecg | dbgeaf ga dagfeb fagdc',
#  'efdab cgadf cbafd fgbcda ebgfdc cfb bc gcba cefgad gfabcde | cagb fcdage bc dacfgeb',
#  'acgfe gcedbf fge dbfacg bgcfa fcbaegd ebga eg feacd egabfc | geab fgabc cfaegb egfcba',
# ...

# %%
count = 0
for line in linesOut:
#     print()
#     print(line, len(line))
    countx = 0
    for x in line:
#         print(len(x), end=' ')
        lenx = len(x)
        if (lenx == 2 or lenx==3 or lenx==4 or lenx==7):
            countx +=1
#     print(countx)
    count += countx

# times1478 = [  for x in linesOut]
count
# Out:
# 264

# %%
for line in zip(linesInp, linesOut):
    print(line)
    dig = {1 : 'z', 4 : 'z', 7 : 'z', 8 : 'abcdefg'}
    print(dig)
    for x in line[0]:
#         print(len(x), end=' ')
        lenx = len(x)
        if lenx == 2:
            dig[1] = ''.join(sorted(x))
        if lenx == 4:
            dig[4] = ''.join(sorted(x))
        if lenx == 3:
            dig[7] = ''.join(sorted(x))
        if lenx == 7:
            dig[8] = ''.join(sorted(x))
    print(dig)
            
    for x in line[0]:
        lenx = len(x)
        if lenx == 6:
            int1 = len(set(dig[1]).intersection(x))
            int4 = len(set(dig[4]).intersection(x))
            int7 = len(set(dig[7]).intersection(x))
            
            if int1 == 1:
                dig[6] = ''.join(sorted(x))
                break
            elif int1 == 2:
#                 es un 9 o un 0
                if int4 == 4:
                    dig[9] = ''.join(sorted(x))
                    break
                elif int4 == 3:
                    dig[0] = ''.join(sorted(x))
                    break
#                 con int7 no obtengo informacion
               
            if int4 == 4:
                dig[9] = ''.join(sorted(x))
                break
            elif int4 == 3:
#                 es un 6 o un 0
                if int1 == 1:
                    dig[6] = ''.join(sorted(x))
                    break
                elif int1 == 2:
                    dig[0] = ''.join(sorted(x))
                    break
                if int7 == 2:
                    dig[6] = ''.join(sorted(x))
                    break
                elif int7 == 3:
                    dig[0] = ''.join(sorted(x))
                
            
            if int7 == 2:
                dig[6] = ''.join(sorted(x))
                break
            elif int7 == 3:
#                 es un 9 o un 0
                if int4 == 4:
                    dig[9] = ''.join(sorted(x))
                    break
                elif int4 == 3:
                    dig[0] = ''.join(sorted(x))
                    break
#             int1 no aporta informacion
            
            
        
        
#         if (lenx == 2 or lenx==3 or lenx==4 or lenx==7):
#             countx +=1
#     print(countx)
    
    
    print(dig)
    print( [  dig[''.join(sorted(x))] for x in line[1]   ]   )
    
    break
#     print(line, len(line))
#     countx = 0

dig
# times1478 = [  for x in linesOut]
# Out:
# (['cdafg', 'dage', 'fgdaec', 'cdbfgae', 'cge', 'gcbdfa', 'fdceb', 'gfceab', 'ge', 'ecfgd'], ['eg', 'eg', 'dfecag', 'ge'])
# {1: 'z', 4: 'z', 7: 'z', 8: 'abcdefg'}
# {1: 'eg', 4: 'adeg', 7: 'ceg', 8: 'abcdefg'}
# {1: 'eg', 4: 'adeg', 7: 'ceg', 8: 'abcdefg', 9: 'acdefg'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_253231/1308723281.py in <module>
#      76
#      77     print(dig)
# ---> 78     print( [  dig[''.join(sorted(x))] for x in line[1]   ]   )
#      79
#      80     break
#
# /tmp/ipykernel_253231/1308723281.py in <listcomp>(.0)
#      76
#      77     print(dig)
# ---> 78     print( [  dig[''.join(sorted(x))] for x in line[1]   ]   )
#      79
#      80     break
#
# KeyError: 'eg'

# %%
# from collections import Counter

s2 = 'qsrqq' 
s1 = 'qqtrr'

len(set(s2).intersection(s1))

# s2.intersection(s1)
# common_letters = Counter(s1) & Counter(s2)  # => {'q': 2, 'r': 1}
# print(sum(common_letters.values()))         # => 3
# Out:
# 2

# %%
total = 0
for line in zip(linesInp, linesOut):
#     print(line[0])
#     dig = {1 : 'z', 4 : 'z', 7 : 'z', 8 : 'abcdefg'}
    dig = {'abcdefg' : '8'}
#     print(dig)
    for x in line[0]:
#         print(len(x), end=' ')
        lenx = len(x)
        if lenx == 2:
            name1 = ''.join(sorted(x))
            dig[name1] = '1'
        if lenx == 4:
            name4 = ''.join(sorted(x))
            dig[name4] = '4'
        if lenx == 3:
            name7 = ''.join(sorted(x))
            dig[name7] = '7'
#         if lenx == 7:
#             dig[''.join(sorted(x))] = 8
#     print(len(dig), end=' ')
#     print(line[1])
    for x in line[1]:
        lenx = len(x)
        int1 = len(set(name1).intersection(x))
        int4 = len(set(name4).intersection(x))
        int7 = len(set(name7).intersection(x))
#         print(x, lenx, int1, int4, int7, '*************  x, lenx, int1, int4, int7')

        if lenx == 6:
            if int1 == 1:
                dig[''.join(sorted(x))] = '6' 
#                 break
            elif int1 == 2:
#                 es un 9 o un 0
                if int4 == 4:
                    dig[''.join(sorted(x))] = '9'
#                     break
                elif int4 == 3:
                    dig[''.join(sorted(x))] = '0'
#                     break
                    
        if lenx == 5:
            if int1 == 2:
                dig[''.join(sorted(x))] = '3'
#                 break
            elif int1 == 1:
                if int4 == 2:
                    dig[''.join(sorted(x))] = '2'
#                     break
                elif int4 == 3:
                    dig[''.join(sorted(x))] = '5'
#                     break
                    
                    
                    
                
                    
#     print('line[1]  ', line[1])    
#     print(dig)
    number = int(''.join([  dig[''.join(sorted(x))] for x in line[1]   ]))
    print( number )
    total += number
    
#     break
            
                    
                    
                    
#                 con int7 no obtengo informacion''.
               
#             if int4 == 4:
#                 dig[9] = ''.join(sorted(x))
#                 break
#             elif int4 == 3:
# #                 es un 6 o un 0
#                 if int1 == 1:
#                     dig[6] = ''.join(sorted(x))
#                     break
#                 elif int1 == 2:
#                     dig[0] = ''.join(sorted(x))
#                     break
#                 if int7 == 2:
#                     dig[6] = ''.join(sorted(x))
#                     break
#                 elif int7 == 3:
#                     dig[0] = ''.join(sorted(x))
                
            
#             if int7 == 2:fegac
#                 dig[6] = ''.join(sofegacrted(x))
#                 break
#             elif int7 == 3:
# #                 es un 9 o un 0
#                 if int4 == 4:
#                     dig[9] = ''.join(sorted(x))
#                     break
#                 elif int4 == 3:
#                     dig[0] = ''.join(sorted(x))
#                     break
# #             int1 no aporta informacion
            
            
        
        
# #         if (lenx == 2 or lenx==3 or lenx==4 or lenx==7):
# #             countx +=1
# #     print(countx)
    
    
#     print(line, len(line))
#     countx = 0

# dig
# times1478 = [  for x in linesOut]
# Out:
# 1191
# 7256
# 9622
# 1154
# 4485
# 9061
# 8197
# 9468
# 103
# 4618
# 4599
# 223
# 960
# 2674
# 8521
# 8359
# 9354
# 8589
# 9503
# 2970
# 9699
# 4537
# 7727
# 6606
# 5632
# 2167
# 6543
# 6054
# 9411
# 2094
# 6803
# 4847
# 3708
# 9106
# 9726
# 8466
# 20
# 2282
# 6744
# 8003
# 5891
# 2956
# 6116
# 8889
# 9785
# 3824
# 6099
# 1498
# 379
# 929
# 1709
# 1509
# 3407
# 4373
# 6041
# 6660
# 8972
# 3123
# 9180
# 8320
# 4039
# 3323
# 2801
# 3572
# 3603
# 7774
# 2727
# 9502
# 428
# 8998
# 4037
# 5688
# 9246
# 9508
# 7065
# 6794
# 9354
# 2490
# 3976
# 2218
# 2202
# 1981
# 6228
# 4466
# 9645
# 5156
# 2293
# 4223
# 5422
# 8432
# 254
# 439
# 9909
# 3483
# 195
# 6023
# 2544
# 9295
# 7279
# 6082
# 1865
# 6239
# 264
# 5066
# 9432
# 4720
# 6616
# 1908
# 4686
# 4297
# 7591
# 6558
# 1420
# 3190
# 9128
# 2821
# 1435
# 1896
# 5406
# 4346
# 9684
# 7782
# 9045
# 9972
# 2095
# 3222
# 9307
# 8278
# 7792
# 7653
# 7229
# 1085
# 5252
# 824
# 6565
# 7570
# 3638
# 1383
# 7657
# 5652
# 5472
# 3402
# 5410
# 4771
# ...

# %%
total
# Out:
# 1063760
