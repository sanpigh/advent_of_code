# %%
import pandas as pd
import numpy as np

with open('input') as f:
    lines_bck = f.read().splitlines()

# df = pd.read_csv('input', header=None, dtype=str)
# df

# %%
lines = [x.replace(' -> ',',') for x in lines_bck]
lenlines = len(lines)
print(lenlines)
lines[:3]
# Out:
# 500
# ['580,438,580,817', '220,987,199,966', '300,674,300,523']

# %%
# linsplit = [x.split(',') for x in lines]
linsplit = [list(map(int, x.split(','))) for x in lines]
linsplit[:3]
# Out:
# [[580, 438, 580, 817], [220, 987, 199, 966], [300, 674, 300, 523]]

# %%
arr = np.array(linsplit)
arr
# Out:
# array([[580, 438, 580, 817],
#        [220, 987, 199, 966],
#        [300, 674, 300, 523],
#        ...,
#        [ 20,  29, 980, 989],
#        [ 37,  41, 255,  41],
#        [368, 823, 302, 823]])

# %%
# Out:
# 11 11 10 11
# 989 989 990 989
# 10 990 11 989

# %%
# Out:
# ......
# ......
# ......
# ......
# ......
# ......

# %%
stack = []
stack_set = []


for r in arr:
#     print(r)
    
    x0 = r[0]
    x1 = r[2]
    y0 = r[1]
    y1 = r[3]
    
    if x0 == x1:
        y_min = min(y0, y1)
        y_max = max(y0, y1)
        for y in range(y_min, y_max+1):
#             stack.append([x0,y])
            stack.append((x0,y))
            
            
    if y0 == y1:
        x_min = min(x0, x1)
        x_max = max(x0, x1)
        for x in range(x_min, x_max+1):
#             stack.append([x,y0])
            stack.append((x,y0))

#     break
np_stack = np.array(stack)

# %%
np_stack
# Out:
# array([[580, 438],
#        [580, 439],
#        [580, 440],
#        ...,
#        [366, 823],
#        [367, 823],
#        [368, 823]])

# %%
arr
# Out:
# array([[580, 438, 580, 817],
#        [220, 987, 199, 966],
#        [300, 674, 300, 523],
#        ...,
#        [ 20,  29, 980, 989],
#        [ 37,  41, 255,  41],
#        [368, 823, 302, 823]])

# %%
min0 = arr[:,0].min()
min2 = arr[:,2].min()
min1 = arr[:,1].min()
min3 = arr[:,3].min()

max0 = arr[:,0].max()
max2 = arr[:,2].max()
max1 = arr[:,1].max()
max3 = arr[:,3].max()

print(min0, min1, min2, min3)
print(max0, max1, max2, max3)

minX = min(min0, min2)
maxX = max(max0, max2)
minY = min(min1, min3)
maxY = max(max1, max3)
print(minX, maxX, minY, maxY)
 

# minX = 0
# maxX = 5
# minY = 0
# maxY = 5
final_ans = 0

len_np_stack = np_stack.shape[0]

for y in range(minY, maxY+1):
    print('y', y)
#     id_y = y-minY
#     print('')
    for x in range(minX, maxX+1):
        print(x, end=' ')
        ans = 0
#         id_x = x-minX
#         print('.', end='')
        
        for r in np_stack:
            if r[0] == x and r[1] == y:
                ans += 1
                
        if ans > 1:
            final_ans += 1
# Out:
# 11 11 10 11
# 989 989 990 989
# 10 990 11 989
# y 11
# ...

# %%
final_ans

# %%
arr
# Out:
# array([[580, 438, 580, 817],
#        [220, 987, 199, 966],
#        [300, 674, 300, 523],
#        ...,
#        [ 20,  29, 980, 989],
#        [ 37,  41, 255,  41],
#        [368, 823, 302, 823]])

# %%
resto = arr.shape[0]


for ind, r in enumerate(arr):
#     print(ind, r)
    x0 = r[0]
    x1 = r[2]
    y0 = r[1]
    y1 = r[3]
    vx = x1-x0
    vy = y1-y0
    
    for i in range(ind+1, resto):
#         print(i)
        rp = arr[i,:]
        xp0 = rp[0]
        xp1 = rp[2]
        yp0 = rp[1]
        yp1 = rp[3]
        vpx = xp1-xp0
        vpy = yp1-yp0
#         print(rp)
        int_prod = vx*vpx + vy*vpy
    
        if int_prod == 0:
            if 
            print(r, rp)
            
        
    break
# Out:
# [580 438 580 817] [890 430 854 430]
# [580 438 580 817] [700 139 531 139]
# [580 438 580 817] [779 635 420 635]
# [580 438 580 817] [601  11 893  11]
# [580 438 580 817] [471 490 900 490]
# [580 438 580 817] [314 475 698 475]
# [580 438 580 817] [ 15 101 335 101]
# [580 438 580 817] [142 321 781 321]
# [580 438 580 817] [248 586 130 586]
# [580 438 580 817] [640 798 153 798]
# [580 438 580 817] [ 24 711 147 711]
# [580 438 580 817] [334 309  43 309]
# [580 438 580 817] [765 630 892 630]
# [580 438 580 817] [ 41 300 606 300]
# [580 438 580 817] [229 348 379 348]
# [580 438 580 817] [196 489 842 489]
# [580 438 580 817] [941 238 206 238]
# [580 438 580 817] [742  28 402  28]
# [580 438 580 817] [513 630 823 630]
# [580 438 580 817] [204 663 179 663]
# [580 438 580 817] [716 192 916 192]
# [580 438 580 817] [529 971 752 971]
# [580 438 580 817] [250 228 348 228]
# [580 438 580 817] [245 760 631 760]
# [580 438 580 817] [328 767 558 767]
# [580 438 580 817] [103 626 937 626]
# ...

# %%
arr
# Out:
# array([[580, 438, 580, 817],
#        [220, 987, 199, 966],
#        [300, 674, 300, 523],
#        ...,
#        [ 20,  29, 980, 989],
#        [ 37,  41, 255,  41],
#        [368, 823, 302, 823]])

# %%
len(stack)
# Out:
# 98816

# %%
set(stack)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_219936/34837826.py in <module>
# ----> 1 set(stack)
#
# TypeError: unhashable type: 'list'

# %%
stack_set = set(tuple(x) for x in stack)

# %%
len(stack_set)
# Out:
# 93138

# %%
98816-931385678
# Out:
# 5678

# %%
len(stack_set)
# Out:
# 98816

# %%
len(set(stack_set))
# Out:
# 93138

# %%
stack_unique = list(set(stack))
len(stack_unique)
# for x in stack_set2:
#     print(stack_set.count(x))
# Out:
# 93138

# %%
adentro = 0
for a in stack_unique:
    print('.', end=' ')
# a = (580,439)
# print(a)
    count = stack.count(a) 
    if count > 1:
        adentro += 1

print('ADENTRO:', adentro)
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 
# ...

# %%
len(stack)
# Out:
# 98816

# %% [markdown]
# ## Second

# %%
stack = []
# stack_set = []


for r in arr:
#     print(r)
    
    x0 = r[0]
    x1 = r[2]
    y0 = r[1]
    y1 = r[3]
    vx = (x1-x0)
    vy = (y1-y0)

    if vx != 0:
        vx = vx//abs(vx)

    if vy != 0:
        vy = vy//abs(vy)

    i = 0
    j = 0 
    x = x0
    y = y0
#     print(x, y, vx, vy)
    print('.', end='')
    while ((x != x1) or (y != y1)):
#         print('.', end='')
        x = i*vx+x0
        y = j*vy+y0
#         print(x,y)
        stack.append((x,y))
        i += 1
        j += 1

    

#     break
# Out:
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
len(stack)
# Out:
# 189708

# %%
stack_unique = list(set(stack))
len(stack_unique)
# Out:
# 165996

# %%
adentro2 = 0

for a in stack_unique:
    print('.', end=' ')
# a = (580,439)
# print(a)
    count = stack.count(a) 
    if count > 1:
        adentro2 += 1

print('ADENTRO:', adentro2)
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 
# ...

# %%
arr[:2,:]
# Out:
# array([[580, 438, 580, 817],
#        [220, 987, 199, 966]])
